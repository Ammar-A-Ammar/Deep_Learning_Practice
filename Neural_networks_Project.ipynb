# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammar-A-Ammar/Deep_Learning_projects/blob/main/Neural_networks_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # Cairo University Faculty of Engineering
# ## Deep Learning
# ## Assignment 2
#
# ---

# %% [markdown]
# Please write your full name here
# - **Name** : "Ammar Ahmed Ammar"

# %%
# !pip install matplotlib_inline
#!apt-get install matplotlib_inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting matplotlib_inline
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.7/dist-packages (from matplotlib_inline) (5.1.1)
# Installing collected packages: matplotlib-inline
# Successfully installed matplotlib-inline-0.1.6

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import random
import tensorflow as tf

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dense
from d2l import tensorflow as d2l
import pandas as pd
import math

from sklearn.datasets import make_blobs  #To generate artificial data
from keras.optimizers import SGD
from keras.utils import to_categorical

# %% [markdown]
# # Part 1 Computational Graphs

# %% [markdown]
# ## Example
# Suppose that we have a function of the form: $f(x,y) = \sigma(x) + (x-y)^2$

# %% [markdown]
# **SHOW YOUR WORK**

# %% [markdown]
# 0. **Draw its computational graph with a minimum of 4 operations inside it. Name your intermediate variables and upload a picture of your graph**

# %% [markdown]
# - Your Answer:
#     - ![Answer](/1.jpg)

# %% [markdown]
# 1. **Compute the forward path for this function. Use intermediate variables you identified in your graph**
#
# - f --> final output
# - Upload a a picture of your graph

# %% [markdown]
# - Your Answer:
#     - ![1.jpg]()

# %% [markdown]
# 2. **Compute the backward path for this function to get:**
# $$
# \nabla f(x,y) = [ \frac{\partial f}{\partial y}, \frac{\partial f}{\partial x} ]
# $$
#
# - Upload a a picture of your graph
# - **Use intermediate variables**
# - **Write df/dy and df/dx**
# - *Hint: Gradients add up at forks. This follows the multivariable chain rule in Calculus, which states that if a variable branches out to different parts, then the gradients that flow back to it will add.*

# %% [markdown]
# - Your Answer:
#     - ![Answer](data:image/jpeg;base64,...)

# %% [markdown]
# # Part 2: Regression

# %% [markdown]
# In this part, (**we will implement the entire linear regression method from scratch,
# including the data pipeline, the model,
# the loss function, and the minibatch stochastic gradient descent optimizer.**)
# You will rely only on tensors and auto differentiation.

# %% [markdown]
# we will use $n$ to denote
# the number of examples in our dataset.
# We index the data examples by $i$, denoting each input
# as $\mathbf{x}^{(i)} = [x_1^{(i)}, x_2^{(i)}]^\top$
# and the corresponding label as $y^{(i)}$.
#
#
# **Linear Model**
#
# When our inputs consist of $d$ features,
# we express our prediction $\hat{y}$ (in general the "hat" symbol denotes estimates) as
#
# $$\hat{y} = w_1  x_1 + ... + w_d  x_d + b.$$
#
#
# We will often find it convenient
# to refer to features of our entire dataset of $n$ examples
# via the *design matrix* $\mathbf{X} \in \mathbb{R}^{n \times d}$.
# Here, $\mathbf{X}$ contains one row for every example
# and one column for every feature.
#
# For a collection of features $\mathbf{X}$,
# the predictions $\hat{\mathbf{y}} \in \mathbb{R}^n$
# can be expressed via the matrix-vector product:
#
# $${\hat{\mathbf{y}}} = \mathbf{X} \mathbf{w} + b,$$
#
#
# **Loss Function**
#
# When our prediction for an example $i$ is $\hat{y}^{(i)}$
# and the corresponding true label is $y^{(i)}$,
# the squared error is given by:
#
# $$l^{(i)}(\mathbf{w}, b) = \frac{1}{2} \left(\hat{y}^{(i)} - y^{(i)}\right)^2.$$
#
# To measure the quality of a model on the entire dataset of $n$ examples,
# we simply average (or equivalently, sum)
# the losses on the training set.
#
# $$L(\mathbf{w}, b) =\frac{1}{n}\sum_{i=1}^n l^{(i)}(\mathbf{w}, b) =\frac{1}{n} \sum_{i=1}^n \frac{1}{2}\left(\mathbf{w}^\top \mathbf{x}^{(i)} + b - y^{(i)}\right)^2.$$
#
# When training the model, we want to find parameters ($\mathbf{w}^*, b^*$)
# that minimize the total loss across all training examples:
#
# $$\mathbf{w}^*, b^* = \operatorname*{argmin}_{\mathbf{w}, b}\  L(\mathbf{w}, b).$$

# %% [markdown]
# **Minibatch Stochastic Gradient Descent**
#
# We can express the update mathematically as follows
# ($\partial$ denotes the partial derivative):
#
# $$(\mathbf{w},b) \leftarrow (\mathbf{w},b) - \frac{\eta}{|\mathcal{B}|} \sum_{i \in \mathcal{B}} \partial_{(\mathbf{w},b)} l^{(i)}(\mathbf{w},b).$$

# %% [markdown]
# ## Synthetic Data, Simple Model
# ### Generating the Dataset
#
# To keep things simple, we will [**construct an artificial dataset
# according to a linear model with additive noise.**]
#
# In the following code snippet, we generate a dataset
# containing 1000 examples, each consisting of 2 features
# sampled from a standard normal distribution.
# Thus our synthetic dataset will be a matrix
# $\mathbf{X}\in \mathbb{R}^{1000 \times 2}$.
#
# (**The true parameters generating our dataset will be
# $\mathbf{w} = [2, -3.4]^\top$ and $b = 4.2$,
# and**) our synthetic labels will be assigned according
# to the following linear model with the noise term $\epsilon$:
#
# (**$$\mathbf{y}= \mathbf{X} \mathbf{w} + b + \mathbf\epsilon.$$**)

# %%
def synthetic_data(w, b, num_examples):  #save
    """Generate y = Xw + b + noise."""
    X = tf.zeros((num_examples, w.shape[0]))
    X += tf.random.normal(shape=X.shape)
    y = tf.matmul(X, tf.reshape(w, (-1, 1))) + b
    y += tf.random.normal(shape=y.shape, stddev=0.01)
    y = tf.reshape(y, (-1, 1))
    return X, y

# %%
tf.random.set_seed(5)
true_w = tf.constant([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)

# %%
print('features:', features[0],'\nlabel:', labels[0])
# Out:
# features: tf.Tensor([-0.18030666 -0.95028627], shape=(2,), dtype=float32)
# label: tf.Tensor([7.0726256], shape=(1,), dtype=float32)

# %% [markdown]
# By generating a scatter plot using the second feature `features[:, 1]` and `labels`,
# we can clearly observe the linear correlation between the two.

# %%
d2l.set_figsize()
# The semicolon is for displaying the plot only
d2l.plt.scatter(features[:, (1)].numpy(), labels.numpy(), 1);

# %% [markdown]
# ### Reading the Dataset
#
# In the following code [**call upon the existing API in a framework to read data.**]
# We pass in `features` and `labels` as arguments and specify `batch_size`
# when instantiating a data iterator object.
# Besides, the boolean value `is_train`
# indicates whether or not
# we want the data iterator object to shuffle the data
# on each epoch (pass through the dataset).

# %% [markdown]
# 1. **Use the tf function from_tensor_slices to generate a tf dataset object with batch_size as input**
# 2. **Use is_train flag to determine whether to shuffle the dataset or not**

# %%
def load_array(data_arrays, batch_size, is_train=True):  #save
    """Construct a TensorFlow data iterator."""
    #### YOUR CODE HERE ###
    dataset = tf.data.Dataset.from_tensor_slices(data_arrays)
    if is_train:
        dataset = dataset.shuffle(buffer_size=1000)
    dataset = dataset.batch(batch_size)
    
    return dataset

# %%
batch_size = 10
data_iter = load_array((features, labels), batch_size)

# %% [markdown]
# 3. **Use `iter` to construct a Python iterator and use `next` to obtain the first item from the iterator.**

# %%
### YOUR CODE HERE ###
next(iter(data_iter))
# Out:
# (<tf.Tensor: shape=(10, 2), dtype=float32, numpy=
#  array([[ 0.3893177 ,  0.58026695],
#         [-0.3781467 , -0.6147702 ],
#         [ 0.9060589 ,  0.10428783],
#         [ 1.0729338 , -0.04161261],
#         [-1.5346323 , -1.0025218 ],
#         [-0.04122835, -0.5331398 ],
#         [-1.6722537 ,  0.4518441 ],
#         [ 0.02458847,  1.6489348 ],
#         [-1.7942764 ,  1.3188082 ],
#         [-0.25043255, -1.52343   ]], dtype=float32)>,
#  <tf.Tensor: shape=(10, 1), dtype=float32, numpy=
#  array([[ 2.9947941],
#         [ 5.5324187],
#         [ 5.649894 ],
#         [ 6.4856396],
#         [ 4.545032 ],
#         [ 5.9349017],
#         [-0.6771385],
#         [-1.3545394],
#         [-3.8587646],
#         [ 8.875017 ]], dtype=float32)>)

# %% [markdown]
# 4. **Explain what the output shape in the prvious tensors means:**

# %% [markdown]
# **Answer:**

# %% [markdown]
# 5. **How many TOTAL batches can be generated by **ENTIRE** data_iter ?** --> batches in data

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### Initializing Model Parameters
#
# 6. **Initialize weights by sampling random numbers from a normal distribution with mean 0 and a standard deviation of 0.01, and setting the bias to 0.**
#
# Note: For the shapes of the weights and bias, look at the generating a dataset part

# %%
## YOUR CODE HERE ##
w = tf.Variable(tf.random.normal(shape=(2, 1), mean=0, stddev=0.01),
                trainable=True)
b = tf.Variable(tf.zeros(1), trainable=True)

# %% [markdown]
# ### Defining the Model
#
# 7. [**define our model, relating its inputs and parameters to its outputs.**]

# %%
def linreg(X, w, b):  
    """The linear regression model."""
    ## YOUR CODE HERE ##
    model = tf.matmul(X, w) + b
    return model

# %% [markdown]
# ### Defining the Loss Function
#
# 8. (**define the loss function**): the squared loss function
# as described in Loss Function definition above.
#
# Note: In the implementation, you need to transform the true value `y`
# into the predicted value's shape `y_hat`.
# The result returned by the following function
# will also have the same shape as `y_hat`.

# %%
def squared_loss(y_hat, y):  
    """Squared loss."""
    ## YOUR CODE HERE ##
    answerLF = (y_hat - tf.reshape(y, y_hat.shape)) ** 2 / 2
    return answerLF

# %% [markdown]
# ### Defining the Optimization Algorithm
#
# At each step, using one minibatch randomly drawn from our dataset,
# we will estimate the gradient of the loss with respect to our parameters.
# Next, we will update our parameters
# in the direction that may reduce the loss.
#
# 9. **Filll in the missing function below to apply the minibatch stochastic gradient descent update, given a set of parameters, a learning rate, and a batch size.**
#
# Note: use assign_sub

# %%
def sgd(params, grads, lr, batch_size):  
    """Minibatch stochastic gradient descent."""
    
    ## YOUR CODE HERE ##
    for param, grad in zip(params, grads):
        param.assign_sub(lr*grad/batch_size)

# %% [markdown]
# ### Training
#
# 10. **Implement the following loop**
#
# * For each epoch :
#     * Initialize parameters $(\mathbf{w}, b)$
#     * Repeat until done
#         * Compute gradient $\mathbf{g} \leftarrow \partial_{(\mathbf{w},b)} \frac{1}{|\mathcal{B}|} \sum_{i \in \mathcal{B}} l(\mathbf{x}^{(i)}, y^{(i)}, \mathbf{w}, b)$
#         * Update parameters $(\mathbf{w}, b) \leftarrow (\mathbf{w}, b) - \eta \mathbf{g}$
#     * Print the loss at the end of each epoch
#
# In each *epoch*,
# we will iterate through the entire dataset
# (using the `data_iter` function) once
# passing through every example in the training dataset
# .
#
#
# Set the number of epochs `num_epochs` and the learning rate `lr` to 3 and 0.03, respectively.

# %%
lr = 0.03
num_epochs = 3
net = linreg
loss = squared_loss

# %%
## YOUR CODE HERE ##
for epoch in range(num_epochs):
    for X, y in data_iter:
        with tf.GradientTape() as g:
            l = loss(net(X, w, b),y)
        dw, db = g.gradient(l, [w, b])
        sgd([w, b], [dw, db], lr, batch_size)
    train_l = loss(net(features, w, b), labels)
    print(f'epoch {epoch + 1}, loss {float(tf.reduce_mean(train_l)):f}')
# Out:
# epoch 1, loss 0.051067
# epoch 2, loss 0.000242
# epoch 3, loss 0.000054

# %% [markdown]
# In this case, because we synthesized the dataset ourselves,
# we know precisely what the true parameters are.
#
# 11. [**evaluate our success in training by comparing the true parameters with those that we learned**] through our training loop. They should turn out to be very close to each other.

# %%
## YOUR CODE HERE ##
print(f'error in estimating w: {true_w - tf.reshape(w, true_w.shape)}')
print(f'error in estimating b: {true_b - b}')
# Out:
# error in estimating w: [-0.00030637 -0.00141144]
# error in estimating b: [0.00111246]

# %% [markdown]
# ## Part 2  Diabetes Dataset

# %% [markdown]
# In this section, we will use SKLEARN's Diabetes dataset

# %% [markdown]
# ### Loading the Dataset

# %% [markdown]
# 1. **Load the Diabetes dataset from sklearn**

# %%
from sklearn.datasets import load_diabetes
## YOUR CODE HERE ##
data,targets=load_diabetes(return_X_y=True)
# Load the diabetes dataset
diabetes=load_diabetes()

# %% [markdown]
# 2. **Look at the keys of diabetes_dataset dictionary**

# %%
## YOUR CODE HERE ##

### Look at keys to determine the data
print(diabetes.feature_names)
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %% [markdown]
# 3. **Use the key DESCR to understand the dataset**

# %%
## YOUR CODE HERE ##
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
#       - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %% [markdown]
# 4. **Save the data and target variables in numpy arrays and print their shapes**

# %%
### START CODE HERE ### (≈ 2 lines of code)
### END CODE HERE ###

print ('The shape of data is: ' + str(data.shape))
print ('The shape of targets is: ' + str(targets.shape))
print ('I have f = %d features!' % (data.shape[1]))
print ('I have m = %d examples!' % (data.shape[0]))
# Out:
# The shape of data is: (442, 10)
# The shape of targets is: (442,)
# I have f = 10 features!
# I have m = 442 examples!

# %% [markdown]
# 5. **What are the ranges of each column in features and the target column?**
#     - *Hint* you might find it helpful to convert to pandas dataframe and use ".describe"

# %%
### START CODE HERE ###
db_df = pd.DataFrame(diabetes.data,columns=diabetes.feature_names)
db_df.describe()
### END CODE HERE ###
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.639623e-16  1.309912e-16 -8.013951e-16  1.289818e-16 -9.042540e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.301121e-16 -4.563971e-16  3.863174e-16 -3.848103e-16 -3.398488e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260974e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324879e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947634e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243323e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335990e-01  1.356118e-01

# %% [markdown]
# ### Preparing the data

# %% [markdown]
# 6. **Split the data into train and test set using sklearn train_test_split.** Have the test set as 10% of data

# %%
np.random.seed(0)
### START CODE HERE ###
# Split the data into train and test sets
from sklearn.model_selection import train_test_split
train_data, test_data, train_targets, test_targets = train_test_split( data, targets, test_size=0.1, random_state=4)
### END CODE HERE ###

print("Shape of training data is", train_data.shape)
print("Shape of training targets is", train_targets.shape)
print("Shape of test data is", test_data.shape)
print("Shape of test targets is", test_targets.shape)
# Out:
# Shape of training data is (397, 10)
# Shape of training targets is (397,)
# Shape of test data is (45, 10)
# Shape of test targets is (45,)

# %% [markdown]
# - *feature-wise normalization*: for each feature in the input data (a column in the input data matrix), we subtract the mean of the feature and divide by the standard deviation, so that the feature is centered around 0 and has a unit standard deviation. This is easily done in NumPy.
# - **Question:** Shold we normalize features? WHY?
#     - ANSWER:

# %% [markdown]
# 7. **normalize the targets using standard normalization**
#
# Hint: Avoid leak between train and test data !!

# %%
### START CODE HERE ### (≈ 6 lines of code)
mean=np.mean(train_targets)
std=np.std(train_targets)
standarded_target_train=(train_targets-mean)/std
mean=np.mean(test_targets)
std=np.std(test_targets)
standarded_target_test=(test_targets-mean)/std
### END CODE HERE ###

# %% [markdown]
# ### Building your model

# %% [markdown]
# 7. **Use tf.keras.Sequential to build a model with:**
#     - 6 hidden layers each having 128 neurons and relu activation.
#     - 1 output layer
#     - use input_shape argument to specify input size in 1st layer
# - **Question:** How many neurons should be in output layer? What should be the activation?
#     - ANSWER: 1  , none

# %%
def build_model(input_shape):
    ### START CODE HERE ### ()

    model = tf.keras.Sequential()
    model.add(tf.keras.Input(shape=input_shape))
    model.add(tf.keras.layers.Dense(128, activation="relu"))
    model.add(tf.keras.layers.Dense(128, activation="relu"))
    model.add(tf.keras.layers.Dense(128, activation="relu"))
    model.add(tf.keras.layers.Dense(128, activation="relu"))
    model.add(tf.keras.layers.Dense(128, activation="relu"))
    model.add(tf.keras.layers.Dense(128, activation="relu"))
    model.add(tf.keras.layers.Dense(1))
    return model

# %%
# Print the model summary
input_shape=(train_data.shape[-1],)
model = build_model(input_shape)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1408
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 84,097
# Trainable params: 84,097
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# 8. **Compile the model using optimizer=Adam, loss=mean squared loss, metrics=mean absoluute error:**

# %%
### START CODE HERE ### ()
(model.compile(optimizer='adam', loss='mean_squared_error',metrics='mean_absolute_error'))

# %% [markdown]
# Note that we compile the model with the mse loss function—mean squared error, the
# square of the difference between the predictions and the targets. We’re also monitoring a new metric during training: mean absolute error (MAE). It’s the
# absolute value of the difference between the predictions and the targets.

# %% [markdown]
# 9. **FIT the model using for 100 epochs, 64 batch size and a validation split of 0.15**

# %%
### START CODE HERE ### ()
history = (model.fit(train_data, standarded_target_train, epochs=100,batch_size=64,validation_split=0.15))
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 67ms/step - loss: 0.9956 - mean_absolute_error: 0.8562 - val_loss: 0.8617 - val_mean_absolute_error: 0.7879
# Epoch 2/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8953 - mean_absolute_error: 0.8014 - val_loss: 0.7071 - val_mean_absolute_error: 0.7144
# Epoch 3/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7018 - mean_absolute_error: 0.6972 - val_loss: 0.5617 - val_mean_absolute_error: 0.6074
# Epoch 4/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5686 - mean_absolute_error: 0.6157 - val_loss: 0.5060 - val_mean_absolute_error: 0.5701
# Epoch 5/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4949 - mean_absolute_error: 0.5697 - val_loss: 0.5252 - val_mean_absolute_error: 0.5643
# Epoch 6/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4621 - mean_absolute_error: 0.5439 - val_loss: 0.5443 - val_mean_absolute_error: 0.5838
# Epoch 7/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4514 - mean_absolute_error: 0.5352 - val_loss: 0.5563 - val_mean_absolute_error: 0.5940
# Epoch 8/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4434 - mean_absolute_error: 0.5332 - val_loss: 0.5290 - val_mean_absolute_error: 0.5795
# Epoch 9/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4316 - mean_absolute_error: 0.5344 - val_loss: 0.5409 - val_mean_absolute_error: 0.5790
# Epoch 10/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4162 - mean_absolute_error: 0.5169 - val_loss: 0.5493 - val_mean_absolute_error: 0.5800
# Epoch 11/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4251 - mean_absolute_error: 0.5189 - val_loss: 0.5936 - val_mean_absolute_error: 0.6083
# Epoch 12/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4438 - mean_absolute_error: 0.5306 - val_loss: 0.5625 - val_mean_absolute_error: 0.5719
# Epoch 13/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4087 - mean_absolute_error: 0.5205 - val_loss: 0.5426 - val_mean_absolute_error: 0.5851
# Epoch 14/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4020 - mean_absolute_error: 0.5039 - val_loss: 0.5712 - val_mean_absolute_error: 0.5869
# Epoch 15/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3898 - mean_absolute_error: 0.4956 - val_loss: 0.6381 - val_mean_absolute_error: 0.6012
# Epoch 16/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4308 - mean_absolute_error: 0.5153 - val_loss: 0.6138 - val_mean_absolute_error: 0.6339
# Epoch 17/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4536 - mean_absolute_error: 0.5422 - val_loss: 0.5918 - val_mean_absolute_error: 0.5733
# Epoch 18/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3906 - mean_absolute_error: 0.4961 - val_loss: 0.5822 - val_mean_absolute_error: 0.6016
# Epoch 19/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3977 - mean_absolute_error: 0.4972 - val_loss: 0.5848 - val_mean_absolute_error: 0.5785
# Epoch 20/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3935 - mean_absolute_error: 0.5022 - val_loss: 0.5751 - val_mean_absolute_error: 0.5872
# Epoch 21/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3773 - mean_absolute_error: 0.4805 - val_loss: 0.5829 - val_mean_absolute_error: 0.5904
# Epoch 22/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3898 - mean_absolute_error: 0.5036 - val_loss: 0.6089 - val_mean_absolute_error: 0.5847
# Epoch 23/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3951 - mean_absolute_error: 0.4912 - val_loss: 0.5667 - val_mean_absolute_error: 0.5834
# Epoch 24/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3651 - mean_absolute_error: 0.4931 - val_loss: 0.5788 - val_mean_absolute_error: 0.5817
# Epoch 25/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3542 - mean_absolute_error: 0.4619 - val_loss: 0.6036 - val_mean_absolute_error: 0.5973
# Epoch 26/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3552 - mean_absolute_error: 0.4711 - val_loss: 0.6165 - val_mean_absolute_error: 0.5868
# Epoch 27/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3543 - mean_absolute_error: 0.4667 - val_loss: 0.5934 - val_mean_absolute_error: 0.6022
# Epoch 28/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3364 - mean_absolute_error: 0.4652 - val_loss: 0.6831 - val_mean_absolute_error: 0.6008
# Epoch 29/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3383 - mean_absolute_error: 0.4472 - val_loss: 0.6590 - val_mean_absolute_error: 0.6569
# Epoch 30/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3524 - mean_absolute_error: 0.4750 - val_loss: 0.6185 - val_mean_absolute_error: 0.5787
# Epoch 31/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3176 - mean_absolute_error: 0.4485 - val_loss: 0.6437 - val_mean_absolute_error: 0.6212
# Epoch 32/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2958 - mean_absolute_error: 0.4246 - val_loss: 0.6959 - val_mean_absolute_error: 0.6147
# Epoch 33/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2946 - mean_absolute_error: 0.4209 - val_loss: 0.6960 - val_mean_absolute_error: 0.6806
# Epoch 34/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.3207 - mean_absolute_error: 0.4479 - val_loss: 0.6371 - val_mean_absolute_error: 0.5944
# Epoch 35/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2794 - mean_absolute_error: 0.4266 - val_loss: 0.6405 - val_mean_absolute_error: 0.6119
# Epoch 36/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2657 - mean_absolute_error: 0.4025 - val_loss: 0.6492 - val_mean_absolute_error: 0.6200
# Epoch 37/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2566 - mean_absolute_error: 0.3927 - val_loss: 0.6998 - val_mean_absolute_error: 0.6475
# Epoch 38/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2610 - mean_absolute_error: 0.3957 - val_loss: 0.7081 - val_mean_absolute_error: 0.6432
# Epoch 39/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2409 - mean_absolute_error: 0.3846 - val_loss: 0.6861 - val_mean_absolute_error: 0.6456
# Epoch 40/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2388 - mean_absolute_error: 0.3798 - val_loss: 0.6970 - val_mean_absolute_error: 0.6196
# Epoch 41/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.2442 - mean_absolute_error: 0.3916 - val_loss: 0.7088 - val_mean_absolute_error: 0.6186
# Epoch 42/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2347 - mean_absolute_error: 0.3811 - val_loss: 0.6903 - val_mean_absolute_error: 0.6151
# Epoch 43/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.2583 - mean_absolute_error: 0.3898 - val_loss: 0.7489 - val_mean_absolute_error: 0.7073
# Epoch 44/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3049 - mean_absolute_error: 0.4200 - val_loss: 0.6835 - val_mean_absolute_error: 0.6741
# Epoch 45/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2768 - mean_absolute_error: 0.4165 - val_loss: 0.6684 - val_mean_absolute_error: 0.5986
# Epoch 46/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2443 - mean_absolute_error: 0.3908 - val_loss: 0.6500 - val_mean_absolute_error: 0.6427
# Epoch 47/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2257 - mean_absolute_error: 0.3660 - val_loss: 0.7461 - val_mean_absolute_error: 0.6977
# Epoch 48/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2042 - mean_absolute_error: 0.3460 - val_loss: 0.6833 - val_mean_absolute_error: 0.6103
# Epoch 49/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1940 - mean_absolute_error: 0.3452 - val_loss: 0.6749 - val_mean_absolute_error: 0.6308
# Epoch 50/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1830 - mean_absolute_error: 0.3333 - val_loss: 0.7545 - val_mean_absolute_error: 0.6723
# Epoch 51/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1737 - mean_absolute_error: 0.3168 - val_loss: 0.7700 - val_mean_absolute_error: 0.6832
# Epoch 52/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1750 - mean_absolute_error: 0.3192 - val_loss: 0.7494 - val_mean_absolute_error: 0.6491
# Epoch 53/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1739 - mean_absolute_error: 0.3161 - val_loss: 0.8601 - val_mean_absolute_error: 0.7636
# Epoch 54/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.2230 - mean_absolute_error: 0.3722 - val_loss: 0.7626 - val_mean_absolute_error: 0.6962
# Epoch 55/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1828 - mean_absolute_error: 0.3295 - val_loss: 0.7559 - val_mean_absolute_error: 0.6238
# Epoch 56/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1809 - mean_absolute_error: 0.3318 - val_loss: 0.6895 - val_mean_absolute_error: 0.6297
# Epoch 57/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1586 - mean_absolute_error: 0.3061 - val_loss: 0.7366 - val_mean_absolute_error: 0.6467
# Epoch 58/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1470 - mean_absolute_error: 0.2870 - val_loss: 0.8101 - val_mean_absolute_error: 0.6829
# Epoch 59/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1479 - mean_absolute_error: 0.2934 - val_loss: 0.7629 - val_mean_absolute_error: 0.6564
# Epoch 60/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1488 - mean_absolute_error: 0.2954 - val_loss: 0.7877 - val_mean_absolute_error: 0.6837
# Epoch 61/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1303 - mean_absolute_error: 0.2655 - val_loss: 0.7489 - val_mean_absolute_error: 0.6675
# Epoch 62/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1362 - mean_absolute_error: 0.2779 - val_loss: 0.8191 - val_mean_absolute_error: 0.7281
# Epoch 63/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1331 - mean_absolute_error: 0.2746 - val_loss: 0.7240 - val_mean_absolute_error: 0.6596
# Epoch 64/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1218 - mean_absolute_error: 0.2636 - val_loss: 0.7699 - val_mean_absolute_error: 0.6435
# Epoch 65/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1295 - mean_absolute_error: 0.2664 - val_loss: 0.8214 - val_mean_absolute_error: 0.7003
# Epoch 66/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1072 - mean_absolute_error: 0.2406 - val_loss: 0.7934 - val_mean_absolute_error: 0.6833
# Epoch 67/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0974 - mean_absolute_error: 0.2290 - val_loss: 0.8002 - val_mean_absolute_error: 0.7003
# Epoch 68/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0870 - mean_absolute_error: 0.2134 - val_loss: 0.7987 - val_mean_absolute_error: 0.6853
# Epoch 69/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0798 - mean_absolute_error: 0.2025 - val_loss: 0.8002 - val_mean_absolute_error: 0.6728
# Epoch 70/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0817 - mean_absolute_error: 0.2046 - val_loss: 0.8346 - val_mean_absolute_error: 0.7092
# Epoch 71/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0758 - mean_absolute_error: 0.2013 - val_loss: 0.8330 - val_mean_absolute_error: 0.7104
# Epoch 72/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0704 - mean_absolute_error: 0.1940 - val_loss: 0.8189 - val_mean_absolute_error: 0.6802
# Epoch 73/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0853 - mean_absolute_error: 0.2204 - val_loss: 0.7861 - val_mean_absolute_error: 0.6758
# Epoch 74/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0868 - mean_absolute_error: 0.2215 - val_loss: 0.8006 - val_mean_absolute_error: 0.6945
# Epoch 75/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0764 - mean_absolute_error: 0.2063 - val_loss: 0.7881 - val_mean_absolute_error: 0.6771
# Epoch 76/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0886 - mean_absolute_error: 0.2294 - val_loss: 0.8393 - val_mean_absolute_error: 0.7214
# Epoch 77/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0911 - mean_absolute_error: 0.2303 - val_loss: 0.7518 - val_mean_absolute_error: 0.6543
# Epoch 78/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1597 - mean_absolute_error: 0.3124 - val_loss: 0.8066 - val_mean_absolute_error: 0.6628
# Epoch 79/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1631 - mean_absolute_error: 0.3151 - val_loss: 0.7358 - val_mean_absolute_error: 0.6583
# Epoch 80/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.1293 - mean_absolute_error: 0.2760 - val_loss: 0.8445 - val_mean_absolute_error: 0.7350
# Epoch 81/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0946 - mean_absolute_error: 0.2355 - val_loss: 0.8015 - val_mean_absolute_error: 0.6870
# Epoch 82/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0868 - mean_absolute_error: 0.2240 - val_loss: 0.8419 - val_mean_absolute_error: 0.7039
# Epoch 83/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0689 - mean_absolute_error: 0.1947 - val_loss: 0.8383 - val_mean_absolute_error: 0.7093
# Epoch 84/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0645 - mean_absolute_error: 0.1897 - val_loss: 0.7552 - val_mean_absolute_error: 0.6598
# Epoch 85/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0542 - mean_absolute_error: 0.1736 - val_loss: 0.7994 - val_mean_absolute_error: 0.6746
# Epoch 86/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0703 - mean_absolute_error: 0.2062 - val_loss: 0.8038 - val_mean_absolute_error: 0.6792
# Epoch 87/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0651 - mean_absolute_error: 0.1990 - val_loss: 0.7897 - val_mean_absolute_error: 0.6661
# Epoch 88/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0824 - mean_absolute_error: 0.2261 - val_loss: 0.8286 - val_mean_absolute_error: 0.7051
# Epoch 89/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0673 - mean_absolute_error: 0.1891 - val_loss: 0.7921 - val_mean_absolute_error: 0.6699
# Epoch 90/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0500 - mean_absolute_error: 0.1744 - val_loss: 0.7962 - val_mean_absolute_error: 0.6772
# Epoch 91/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0431 - mean_absolute_error: 0.1554 - val_loss: 0.8784 - val_mean_absolute_error: 0.7360
# Epoch 92/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0417 - mean_absolute_error: 0.1510 - val_loss: 0.8279 - val_mean_absolute_error: 0.6836
# Epoch 93/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0393 - mean_absolute_error: 0.1498 - val_loss: 0.8948 - val_mean_absolute_error: 0.7352
# Epoch 94/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0459 - mean_absolute_error: 0.1617 - val_loss: 0.8648 - val_mean_absolute_error: 0.7225
# Epoch 95/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0452 - mean_absolute_error: 0.1641 - val_loss: 0.8521 - val_mean_absolute_error: 0.7222
# Epoch 96/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0325 - mean_absolute_error: 0.1333 - val_loss: 0.8601 - val_mean_absolute_error: 0.7107
# Epoch 97/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0284 - mean_absolute_error: 0.1227 - val_loss: 0.8861 - val_mean_absolute_error: 0.7291
# Epoch 98/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0284 - mean_absolute_error: 0.1289 - val_loss: 0.8964 - val_mean_absolute_error: 0.7266
# Epoch 99/100
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0262 - mean_absolute_error: 0.1196 - val_loss: 0.9261 - val_mean_absolute_error: 0.7369
# Epoch 100/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0419 - mean_absolute_error: 0.1625 - val_loss: 0.9328 - val_mean_absolute_error: 0.7564

# %%
# Evaluate the model on the test set

model.evaluate(test_data, test_targets, verbose=2)
# Out:
# 2/2 - 0s - loss: 27535.3633 - mean_absolute_error: 149.2527 - 14ms/epoch - 7ms/step
# [27535.36328125, 149.25271606445312]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Plot the training and validation loss

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# 9. **Diagnose the learning curve:**
#     - Why is the validation loss much higher than training loss?
#     - What's this phenomenon called?
#     - Mention 3 methods to reduce this.

# %% [markdown]
# - **answer**:
#     - __model is unaccurately in training the data, which results in huge errors__
#     - __under-fitting__
#     - __longer training is essential to reduce the loss occured during training.Also, increase the training data either by obtaining more samples oaugmenting the data, or using feature selection__

# %% [markdown]
# 10. **Use one of the methods you mentioned and retrain the model then plot the learning curves**

# %%
#### YOUR CODE HERE
history=model.fit(train_data, standarded_target_train, epochs=150,batch_size=32,validation_split=0.05)
model.evaluate(test_data, standarded_target_test, verbose=2)
# Out:
# Epoch 1/150
# 12/12 [==============================] - 0s 10ms/step - loss: 0.1392 - mean_absolute_error: 0.2454 - val_loss: 1.0044 - val_mean_absolute_error: 0.7898
# Epoch 2/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1269 - mean_absolute_error: 0.2491 - val_loss: 1.1053 - val_mean_absolute_error: 0.8509
# Epoch 3/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1402 - mean_absolute_error: 0.2724 - val_loss: 0.8680 - val_mean_absolute_error: 0.7518
# Epoch 4/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1164 - mean_absolute_error: 0.2552 - val_loss: 1.1640 - val_mean_absolute_error: 0.8866
# Epoch 5/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1258 - mean_absolute_error: 0.2617 - val_loss: 0.9650 - val_mean_absolute_error: 0.8031
# Epoch 6/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1073 - mean_absolute_error: 0.2397 - val_loss: 0.9769 - val_mean_absolute_error: 0.8117
# Epoch 7/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1035 - mean_absolute_error: 0.2342 - val_loss: 0.9079 - val_mean_absolute_error: 0.7875
# Epoch 8/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0994 - mean_absolute_error: 0.2342 - val_loss: 0.9083 - val_mean_absolute_error: 0.7710
# Epoch 9/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0956 - mean_absolute_error: 0.2282 - val_loss: 0.9017 - val_mean_absolute_error: 0.7578
# Epoch 10/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0863 - mean_absolute_error: 0.2263 - val_loss: 0.9021 - val_mean_absolute_error: 0.7718
# Epoch 11/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0903 - mean_absolute_error: 0.2245 - val_loss: 1.0221 - val_mean_absolute_error: 0.7982
# Epoch 12/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0691 - mean_absolute_error: 0.1962 - val_loss: 1.0082 - val_mean_absolute_error: 0.7698
# Epoch 13/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0761 - mean_absolute_error: 0.2037 - val_loss: 1.2089 - val_mean_absolute_error: 0.8593
# Epoch 14/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1149 - mean_absolute_error: 0.2611 - val_loss: 1.0616 - val_mean_absolute_error: 0.8155
# Epoch 15/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0729 - mean_absolute_error: 0.2052 - val_loss: 1.0028 - val_mean_absolute_error: 0.7867
# Epoch 16/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0521 - mean_absolute_error: 0.1757 - val_loss: 1.0715 - val_mean_absolute_error: 0.7954
# Epoch 17/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0439 - mean_absolute_error: 0.1547 - val_loss: 1.0467 - val_mean_absolute_error: 0.8211
# Epoch 18/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0343 - mean_absolute_error: 0.1361 - val_loss: 0.9156 - val_mean_absolute_error: 0.7410
# Epoch 19/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0385 - mean_absolute_error: 0.1484 - val_loss: 1.0115 - val_mean_absolute_error: 0.7994
# Epoch 20/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0371 - mean_absolute_error: 0.1410 - val_loss: 0.9459 - val_mean_absolute_error: 0.7701
# Epoch 21/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0300 - mean_absolute_error: 0.1293 - val_loss: 0.9377 - val_mean_absolute_error: 0.7473
# Epoch 22/150
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0326 - mean_absolute_error: 0.1392 - val_loss: 0.8631 - val_mean_absolute_error: 0.7096
# Epoch 23/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0463 - mean_absolute_error: 0.1658 - val_loss: 0.9379 - val_mean_absolute_error: 0.7426
# Epoch 24/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0382 - mean_absolute_error: 0.1464 - val_loss: 0.9116 - val_mean_absolute_error: 0.7759
# Epoch 25/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0470 - mean_absolute_error: 0.1658 - val_loss: 0.9779 - val_mean_absolute_error: 0.7738
# Epoch 26/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0315 - mean_absolute_error: 0.1274 - val_loss: 0.9688 - val_mean_absolute_error: 0.7677
# Epoch 27/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0245 - mean_absolute_error: 0.1188 - val_loss: 0.9807 - val_mean_absolute_error: 0.7607
# Epoch 28/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0242 - mean_absolute_error: 0.1191 - val_loss: 0.9412 - val_mean_absolute_error: 0.7518
# Epoch 29/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0199 - mean_absolute_error: 0.1084 - val_loss: 1.0269 - val_mean_absolute_error: 0.7926
# Epoch 30/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0186 - mean_absolute_error: 0.1030 - val_loss: 0.9451 - val_mean_absolute_error: 0.7419
# Epoch 31/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0161 - mean_absolute_error: 0.0983 - val_loss: 0.9375 - val_mean_absolute_error: 0.7520
# Epoch 32/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0195 - mean_absolute_error: 0.1088 - val_loss: 0.9380 - val_mean_absolute_error: 0.7619
# Epoch 33/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0213 - mean_absolute_error: 0.1111 - val_loss: 0.9301 - val_mean_absolute_error: 0.7342
# Epoch 34/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0166 - mean_absolute_error: 0.0977 - val_loss: 0.9780 - val_mean_absolute_error: 0.7554
# Epoch 35/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0183 - mean_absolute_error: 0.1030 - val_loss: 0.9895 - val_mean_absolute_error: 0.7638
# Epoch 36/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0189 - mean_absolute_error: 0.1052 - val_loss: 0.9863 - val_mean_absolute_error: 0.7897
# Epoch 37/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0193 - mean_absolute_error: 0.1056 - val_loss: 1.0137 - val_mean_absolute_error: 0.7736
# Epoch 38/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0272 - mean_absolute_error: 0.1304 - val_loss: 0.9391 - val_mean_absolute_error: 0.7504
# Epoch 39/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0345 - mean_absolute_error: 0.1465 - val_loss: 0.9868 - val_mean_absolute_error: 0.7594
# Epoch 40/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0531 - mean_absolute_error: 0.1781 - val_loss: 0.9434 - val_mean_absolute_error: 0.7746
# Epoch 41/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0443 - mean_absolute_error: 0.1633 - val_loss: 0.9436 - val_mean_absolute_error: 0.7891
# Epoch 42/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0313 - mean_absolute_error: 0.1367 - val_loss: 0.8806 - val_mean_absolute_error: 0.7224
# Epoch 43/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0194 - mean_absolute_error: 0.1080 - val_loss: 0.9345 - val_mean_absolute_error: 0.7301
# Epoch 44/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0155 - mean_absolute_error: 0.0957 - val_loss: 0.9493 - val_mean_absolute_error: 0.7522
# Epoch 45/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0132 - mean_absolute_error: 0.0880 - val_loss: 0.9578 - val_mean_absolute_error: 0.7481
# Epoch 46/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0131 - mean_absolute_error: 0.0876 - val_loss: 0.9610 - val_mean_absolute_error: 0.7559
# Epoch 47/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0123 - mean_absolute_error: 0.0835 - val_loss: 1.0125 - val_mean_absolute_error: 0.8000
# Epoch 48/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0159 - mean_absolute_error: 0.0991 - val_loss: 0.9477 - val_mean_absolute_error: 0.7299
# Epoch 49/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0111 - mean_absolute_error: 0.0819 - val_loss: 0.9385 - val_mean_absolute_error: 0.7490
# Epoch 50/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0145 - mean_absolute_error: 0.0962 - val_loss: 0.9442 - val_mean_absolute_error: 0.7432
# Epoch 51/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0097 - mean_absolute_error: 0.0757 - val_loss: 0.9619 - val_mean_absolute_error: 0.7480
# Epoch 52/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0645 - val_loss: 0.9776 - val_mean_absolute_error: 0.7517
# Epoch 53/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0054 - mean_absolute_error: 0.0562 - val_loss: 0.9638 - val_mean_absolute_error: 0.7513
# Epoch 54/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0496 - val_loss: 0.9727 - val_mean_absolute_error: 0.7598
# Epoch 55/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - mean_absolute_error: 0.0527 - val_loss: 0.9337 - val_mean_absolute_error: 0.7448
# Epoch 56/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0039 - mean_absolute_error: 0.0461 - val_loss: 0.9693 - val_mean_absolute_error: 0.7482
# Epoch 57/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042 - mean_absolute_error: 0.0503 - val_loss: 0.9538 - val_mean_absolute_error: 0.7424
# Epoch 58/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0037 - mean_absolute_error: 0.0457 - val_loss: 0.9927 - val_mean_absolute_error: 0.7654
# Epoch 59/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033 - mean_absolute_error: 0.0439 - val_loss: 0.9488 - val_mean_absolute_error: 0.7461
# Epoch 60/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0429 - val_loss: 0.9719 - val_mean_absolute_error: 0.7495
# Epoch 61/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0028 - mean_absolute_error: 0.0397 - val_loss: 0.9420 - val_mean_absolute_error: 0.7332
# Epoch 62/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0029 - mean_absolute_error: 0.0404 - val_loss: 0.9757 - val_mean_absolute_error: 0.7501
# Epoch 63/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0361 - val_loss: 0.9579 - val_mean_absolute_error: 0.7502
# Epoch 64/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0028 - mean_absolute_error: 0.0400 - val_loss: 0.9577 - val_mean_absolute_error: 0.7415
# Epoch 65/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - mean_absolute_error: 0.0440 - val_loss: 0.9232 - val_mean_absolute_error: 0.7244
# Epoch 66/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033 - mean_absolute_error: 0.0442 - val_loss: 0.9491 - val_mean_absolute_error: 0.7337
# Epoch 67/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0432 - val_loss: 0.9357 - val_mean_absolute_error: 0.7347
# Epoch 68/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0036 - mean_absolute_error: 0.0458 - val_loss: 0.9302 - val_mean_absolute_error: 0.7320
# Epoch 69/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0048 - mean_absolute_error: 0.0535 - val_loss: 0.9352 - val_mean_absolute_error: 0.7363
# Epoch 70/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0102 - mean_absolute_error: 0.0783 - val_loss: 0.9701 - val_mean_absolute_error: 0.7486
# Epoch 71/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0124 - mean_absolute_error: 0.0873 - val_loss: 0.9813 - val_mean_absolute_error: 0.7615
# Epoch 72/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0111 - mean_absolute_error: 0.0800 - val_loss: 0.9879 - val_mean_absolute_error: 0.7688
# Epoch 73/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0094 - mean_absolute_error: 0.0766 - val_loss: 0.9045 - val_mean_absolute_error: 0.7396
# Epoch 74/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0106 - mean_absolute_error: 0.0807 - val_loss: 0.9239 - val_mean_absolute_error: 0.7330
# Epoch 75/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0112 - mean_absolute_error: 0.0818 - val_loss: 0.9459 - val_mean_absolute_error: 0.7602
# Epoch 76/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0145 - mean_absolute_error: 0.0931 - val_loss: 0.9646 - val_mean_absolute_error: 0.7569
# Epoch 77/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0139 - mean_absolute_error: 0.0908 - val_loss: 0.9806 - val_mean_absolute_error: 0.7675
# Epoch 78/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0120 - mean_absolute_error: 0.0865 - val_loss: 0.9526 - val_mean_absolute_error: 0.7487
# Epoch 79/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0118 - mean_absolute_error: 0.0836 - val_loss: 0.9231 - val_mean_absolute_error: 0.7408
# Epoch 80/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0085 - mean_absolute_error: 0.0723 - val_loss: 0.9471 - val_mean_absolute_error: 0.7239
# Epoch 81/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0093 - mean_absolute_error: 0.0761 - val_loss: 0.9170 - val_mean_absolute_error: 0.7367
# Epoch 82/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0113 - mean_absolute_error: 0.0822 - val_loss: 0.9405 - val_mean_absolute_error: 0.7613
# Epoch 83/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0141 - mean_absolute_error: 0.0914 - val_loss: 0.9624 - val_mean_absolute_error: 0.7882
# Epoch 84/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0196 - mean_absolute_error: 0.1062 - val_loss: 0.9411 - val_mean_absolute_error: 0.7603
# Epoch 85/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0152 - mean_absolute_error: 0.0942 - val_loss: 0.8860 - val_mean_absolute_error: 0.7234
# Epoch 86/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0128 - mean_absolute_error: 0.0879 - val_loss: 0.8728 - val_mean_absolute_error: 0.7104
# Epoch 87/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0121 - mean_absolute_error: 0.0850 - val_loss: 0.9541 - val_mean_absolute_error: 0.7398
# Epoch 88/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0119 - mean_absolute_error: 0.0830 - val_loss: 0.9882 - val_mean_absolute_error: 0.7529
# Epoch 89/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0090 - mean_absolute_error: 0.0729 - val_loss: 0.9580 - val_mean_absolute_error: 0.7566
# Epoch 90/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0055 - mean_absolute_error: 0.0574 - val_loss: 0.9321 - val_mean_absolute_error: 0.7342
# Epoch 91/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0050 - mean_absolute_error: 0.0562 - val_loss: 0.9664 - val_mean_absolute_error: 0.7585
# Epoch 92/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0073 - mean_absolute_error: 0.0663 - val_loss: 1.0127 - val_mean_absolute_error: 0.7776
# Epoch 93/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0101 - mean_absolute_error: 0.0790 - val_loss: 0.9663 - val_mean_absolute_error: 0.7626
# Epoch 94/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0064 - mean_absolute_error: 0.0619 - val_loss: 0.9456 - val_mean_absolute_error: 0.7343
# Epoch 95/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0049 - mean_absolute_error: 0.0548 - val_loss: 0.9272 - val_mean_absolute_error: 0.7385
# Epoch 96/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042 - mean_absolute_error: 0.0488 - val_loss: 0.9552 - val_mean_absolute_error: 0.7598
# Epoch 97/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0057 - mean_absolute_error: 0.0589 - val_loss: 0.9599 - val_mean_absolute_error: 0.7568
# Epoch 98/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0140 - mean_absolute_error: 0.0916 - val_loss: 0.9083 - val_mean_absolute_error: 0.7188
# Epoch 99/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0149 - mean_absolute_error: 0.0908 - val_loss: 0.9237 - val_mean_absolute_error: 0.7455
# Epoch 100/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0117 - mean_absolute_error: 0.0786 - val_loss: 0.9866 - val_mean_absolute_error: 0.7775
# Epoch 101/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0117 - mean_absolute_error: 0.0816 - val_loss: 0.9655 - val_mean_absolute_error: 0.7736
# Epoch 102/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0823 - val_loss: 0.8922 - val_mean_absolute_error: 0.7112
# Epoch 103/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0129 - mean_absolute_error: 0.0858 - val_loss: 0.8771 - val_mean_absolute_error: 0.7115
# Epoch 104/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0109 - mean_absolute_error: 0.0779 - val_loss: 0.9382 - val_mean_absolute_error: 0.7422
# Epoch 105/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0076 - mean_absolute_error: 0.0687 - val_loss: 0.9793 - val_mean_absolute_error: 0.7654
# Epoch 106/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_absolute_error: 0.0600 - val_loss: 0.9228 - val_mean_absolute_error: 0.7366
# Epoch 107/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0049 - mean_absolute_error: 0.0528 - val_loss: 0.9588 - val_mean_absolute_error: 0.7604
# Epoch 108/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - mean_absolute_error: 0.0620 - val_loss: 0.9067 - val_mean_absolute_error: 0.7331
# Epoch 109/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0083 - mean_absolute_error: 0.0708 - val_loss: 0.9280 - val_mean_absolute_error: 0.7565
# Epoch 110/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0117 - mean_absolute_error: 0.0846 - val_loss: 0.9379 - val_mean_absolute_error: 0.7394
# Epoch 111/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0129 - mean_absolute_error: 0.0884 - val_loss: 0.9323 - val_mean_absolute_error: 0.7619
# Epoch 112/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0298 - mean_absolute_error: 0.1300 - val_loss: 0.8550 - val_mean_absolute_error: 0.7153
# Epoch 113/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0302 - mean_absolute_error: 0.1287 - val_loss: 1.0019 - val_mean_absolute_error: 0.7796
# Epoch 114/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0399 - mean_absolute_error: 0.1525 - val_loss: 0.7258 - val_mean_absolute_error: 0.6552
# Epoch 115/150
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0439 - mean_absolute_error: 0.1531 - val_loss: 0.8514 - val_mean_absolute_error: 0.7188
# Epoch 116/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0438 - mean_absolute_error: 0.1639 - val_loss: 0.8707 - val_mean_absolute_error: 0.7237
# Epoch 117/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0252 - mean_absolute_error: 0.1231 - val_loss: 0.8933 - val_mean_absolute_error: 0.7511
# Epoch 118/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0205 - mean_absolute_error: 0.1109 - val_loss: 0.9502 - val_mean_absolute_error: 0.7551
# Epoch 119/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0176 - mean_absolute_error: 0.1026 - val_loss: 0.9120 - val_mean_absolute_error: 0.7675
# Epoch 120/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0177 - mean_absolute_error: 0.0952 - val_loss: 1.0180 - val_mean_absolute_error: 0.8041
# Epoch 121/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0144 - mean_absolute_error: 0.0944 - val_loss: 0.9219 - val_mean_absolute_error: 0.7483
# Epoch 122/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0096 - mean_absolute_error: 0.0763 - val_loss: 0.9153 - val_mean_absolute_error: 0.7410
# Epoch 123/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0058 - mean_absolute_error: 0.0591 - val_loss: 0.9601 - val_mean_absolute_error: 0.7649
# Epoch 124/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0059 - mean_absolute_error: 0.0600 - val_loss: 0.9065 - val_mean_absolute_error: 0.7291
# Epoch 125/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0048 - mean_absolute_error: 0.0541 - val_loss: 0.9147 - val_mean_absolute_error: 0.7423
# Epoch 126/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0036 - mean_absolute_error: 0.0466 - val_loss: 0.8971 - val_mean_absolute_error: 0.7397
# Epoch 127/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0038 - mean_absolute_error: 0.0502 - val_loss: 0.8841 - val_mean_absolute_error: 0.7239
# Epoch 128/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0433 - val_loss: 0.8782 - val_mean_absolute_error: 0.7294
# Epoch 129/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035 - mean_absolute_error: 0.0457 - val_loss: 0.9222 - val_mean_absolute_error: 0.7468
# Epoch 130/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031 - mean_absolute_error: 0.0426 - val_loss: 0.9402 - val_mean_absolute_error: 0.7498
# Epoch 131/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0026 - mean_absolute_error: 0.0402 - val_loss: 0.8947 - val_mean_absolute_error: 0.7320
# Epoch 132/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0030 - mean_absolute_error: 0.0435 - val_loss: 0.9184 - val_mean_absolute_error: 0.7540
# Epoch 133/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0031 - mean_absolute_error: 0.0425 - val_loss: 0.9078 - val_mean_absolute_error: 0.7377
# Epoch 134/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0438 - val_loss: 0.9217 - val_mean_absolute_error: 0.7388
# Epoch 135/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0034 - mean_absolute_error: 0.0452 - val_loss: 0.9277 - val_mean_absolute_error: 0.7440
# Epoch 136/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0026 - mean_absolute_error: 0.0385 - val_loss: 0.9163 - val_mean_absolute_error: 0.7440
# Epoch 137/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0336 - val_loss: 0.9246 - val_mean_absolute_error: 0.7508
# Epoch 138/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0329 - val_loss: 0.9229 - val_mean_absolute_error: 0.7422
# Epoch 139/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0286 - val_loss: 0.9371 - val_mean_absolute_error: 0.7538
# Epoch 140/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0298 - val_loss: 0.8823 - val_mean_absolute_error: 0.7233
# Epoch 141/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0267 - val_loss: 0.8875 - val_mean_absolute_error: 0.7275
# Epoch 142/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0298 - val_loss: 0.8880 - val_mean_absolute_error: 0.7302
# Epoch 143/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0255 - val_loss: 0.9076 - val_mean_absolute_error: 0.7336
# Epoch 144/150
# 12/12 [==============================] - 0s 4ms/step - loss: 6.9597e-04 - mean_absolute_error: 0.0202 - val_loss: 0.8970 - val_mean_absolute_error: 0.7332
# Epoch 145/150
# 12/12 [==============================] - 0s 5ms/step - loss: 7.5328e-04 - mean_absolute_error: 0.0208 - val_loss: 0.9083 - val_mean_absolute_error: 0.7380
# Epoch 146/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0290 - val_loss: 0.9351 - val_mean_absolute_error: 0.7428
# Epoch 147/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0275 - val_loss: 0.8833 - val_mean_absolute_error: 0.7231
# Epoch 148/150
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0278 - val_loss: 0.9053 - val_mean_absolute_error: 0.7312
# Epoch 149/150
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0010 - mean_absolute_error: 0.0245 - val_loss: 0.9165 - val_mean_absolute_error: 0.7405
# Epoch 150/150
# 12/12 [==============================] - 0s 4ms/step - loss: 9.8030e-04 - mean_absolute_error: 0.0240 - val_loss: 0.8990 - val_mean_absolute_error: 0.7282
# 2/2 - 0s - loss: 0.5967 - mean_absolute_error: 0.5600 - 14ms/epoch - 7ms/step
# [0.5966919660568237, 0.5600218772888184]

# %% [markdown]
# # Part 3 Batches and Epochs

# %% [markdown]
# In this part of the assignment we will create a synthetic data to play with.
# The data will have 2 features and 3 target classes --> multiclass classification problem

# %%
# prepare train and test dataset
def prepare_data():
    #  generate classification dataset with 3 centers (labels/classes)
    X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=2)
    
    # plot data
    for class_value in range(3):
        # select indices of points with the class label
        row_ix = np.where(y == class_value)
        # scatter plot for points with a different color
        plt.scatter(X[row_ix, 0], X[row_ix, 1])
    # show plot
    plt.show()

    # one hot encode output variable to convert from integers to binary class
    y = to_categorical(y)

    # split into train and test
    n_train = 500
    X_train, X_test = X[:n_train, :], X[n_train:, :]
    y_train, y_test = y[:n_train], y[n_train:]
    return X_train, y_train, X_test, y_test

# %%
# prepare dataset
X_train, y_train, X_test, y_test = prepare_data()

# %% [markdown]
# - **Create a model with:**
#     -  1 hidden dense layer (50 neurons), activation relu, , kernel_initializer he_uniform
#     - 1 output layer
#     - compile the model with SGD (learning rate 0.01 and momentum 0.9) optimizer and categorical crossentropy and accuracy inside build function

# %%
def build_model():
    
    ##### YOUR CODE HERE
    initializer = tf.keras.initializers.HeUniform()
    model=tf.keras.models.Sequential([
    tf.keras.layers.Dense(50, activation=tf.nn.relu,kernel_initializer=initializer),
    tf.keras.layers.Dense(3,activation=tf.nn.softmax)
    ])    
   
    # compile model
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.01,momentum=0.9),loss=tf.keras.losses.categorical_crossentropy,metrics='accuracy')
    
    return model

# %% [markdown]
# - Create a function to fit and build the model with different batch sizes

# %% [markdown]
# Use epochs = 125

# %%
# fit a model and plot learning curve
def fit_model(X_train, y_train, X_test, y_test, n_batch):
    ##### YOUR CODE HERE
    model = build_model()
    # fit model
    history=model.fit(X_train,y_train, epochs=125, batch_size= n_batch,validation_split=0.15)

    return history

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# #### Batch size

# %% [markdown]
# ##### Size =  1

# %% [markdown]
# 10. **train for 1 batch size**

# %%
### START CODE HERE ### 
history = fit_model(X_train=X_train,y_train=y_train,X_test=X_test,y_test=y_test,n_batch=1)
###### END CODE HERE
# Out:
# Epoch 1/125
# 425/425 [==============================] - 1s 1ms/step - loss: 1.5160 - accuracy: 0.5388 - val_loss: 1.3982 - val_accuracy: 0.4800
# Epoch 2/125
# 425/425 [==============================] - 0s 1ms/step - loss: 1.0312 - accuracy: 0.4518 - val_loss: 0.9842 - val_accuracy: 0.5600
# Epoch 3/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9338 - accuracy: 0.4753 - val_loss: 0.5733 - val_accuracy: 0.8000
# Epoch 4/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9051 - accuracy: 0.5435 - val_loss: 0.9227 - val_accuracy: 0.6667
# Epoch 5/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9702 - accuracy: 0.5082 - val_loss: 0.9503 - val_accuracy: 0.4400
# Epoch 6/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9461 - accuracy: 0.5294 - val_loss: 0.9881 - val_accuracy: 0.3867
# Epoch 7/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9076 - accuracy: 0.5624 - val_loss: 1.0455 - val_accuracy: 0.4800
# Epoch 8/125
# 425/425 [==============================] - 0s 1ms/step - loss: 0.8955 - accuracy: 0.5788 - val_loss: 0.8207 - val_accuracy: 0.6533
# Epoch 9/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8561 - accuracy: 0.6000 - val_loss: 0.7114 - val_accuracy: 0.7600
# Epoch 10/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.6932 - accuracy: 0.7200 - val_loss: 0.6611 - val_accuracy: 0.7867
# Epoch 11/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9020 - accuracy: 0.5459 - val_loss: 1.0011 - val_accuracy: 0.4800
# Epoch 12/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8298 - accuracy: 0.6000 - val_loss: 0.8334 - val_accuracy: 0.6400
# Epoch 13/125
# 425/425 [==============================] - 1s 1ms/step - loss: 1.0171 - accuracy: 0.5365 - val_loss: 1.0609 - val_accuracy: 0.6400
# Epoch 14/125
# 425/425 [==============================] - 1s 1ms/step - loss: 1.0805 - accuracy: 0.5271 - val_loss: 1.2161 - val_accuracy: 0.5733
# Epoch 15/125
# 425/425 [==============================] - 0s 1ms/step - loss: 0.9950 - accuracy: 0.4988 - val_loss: 0.9775 - val_accuracy: 0.4133
# Epoch 16/125
# 425/425 [==============================] - 0s 1ms/step - loss: 0.9428 - accuracy: 0.5129 - val_loss: 0.9806 - val_accuracy: 0.5333
# Epoch 17/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9635 - accuracy: 0.5176 - val_loss: 1.0318 - val_accuracy: 0.5733
# Epoch 18/125
# 425/425 [==============================] - 1s 1ms/step - loss: 1.0223 - accuracy: 0.4259 - val_loss: 0.9892 - val_accuracy: 0.5200
# Epoch 19/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9600 - accuracy: 0.5059 - val_loss: 1.2635 - val_accuracy: 0.5867
# Epoch 20/125
# 425/425 [==============================] - 0s 1ms/step - loss: 0.9632 - accuracy: 0.4753 - val_loss: 1.0120 - val_accuracy: 0.4667
# Epoch 21/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9766 - accuracy: 0.4847 - val_loss: 1.0283 - val_accuracy: 0.4667
# Epoch 22/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9858 - accuracy: 0.5035 - val_loss: 0.9307 - val_accuracy: 0.5467
# Epoch 23/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9940 - accuracy: 0.5294 - val_loss: 1.1375 - val_accuracy: 0.5733
# Epoch 24/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9614 - accuracy: 0.5294 - val_loss: 1.0312 - val_accuracy: 0.6400
# Epoch 25/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9131 - accuracy: 0.5906 - val_loss: 0.9335 - val_accuracy: 0.5733
# Epoch 26/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.
125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9673 - accuracy: 0.5835 - val_loss: 0.9104 - val_accuracy: 0.6933
# Epoch 57/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8255 - accuracy: 0.6706 - val_loss: 0.8203 - val_accuracy: 0.7333
# Epoch 58/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8703 - accuracy: 0.5624 - val_loss: 0.9013 - val_accuracy: 0.6533
# Epoch 59/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.7807 - accuracy: 0.6541 - val_loss: 1.0391 - val_accuracy: 0.5867
# Epoch 60/125
# 425/425 [==============================] - 0s 1ms/step - loss: 0.7625 - accuracy: 0.6682 - val_loss: 0.8214 - val_accuracy: 0.6933
# Epoch 61/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8201 - accuracy: 0.6235 - val_loss: 0.9454 - val_accuracy: 0.6133
# Epoch 62/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9139 - accuracy: 0.5529 - val_loss: 0.9840 - val_accuracy: 0.6933
# Epoch 63/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.7994 - accuracy: 0.6635 - val_loss: 0.8280 - val_accuracy: 0.6667
# Epoch 64/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9178 - accuracy: 0.5694 - val_loss: 1.5966 - val_accuracy: 0.6133
# Epoch 65/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9537 - accuracy: 0.5765 - val_loss: 1.5394 - val_accuracy: 0.5600
# Epoch 66/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9340 - accuracy: 0.5576 - val_loss: 1.0829 - val_accuracy: 0.5733
# Epoch 67/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8314 - accuracy: 0.5929 - val_loss: 0.9791 - val_accuracy: 0.6800
# Epoch 68/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8250 - accuracy: 0.6353 - val_loss: 1.3168 - val_accuracy: 0.4133
# Epoch 69/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.7858 - accuracy: 0.6565 - val_loss: 0.6298 - val_accuracy: 0.7733
# Epoch 70/125
# 425/425 [==============================] - 1s 1ms/step - loss: 1.0485 - accuracy: 0.5271 - val_loss: 1.4097 - val_accuracy: 0.4533
# Epoch 71/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9760 - accuracy: 0.5129 - val_loss: 0.9769 - val_accuracy: 0.5600
# Epoch 72/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9392 - accuracy: 0.4871 - val_loss: 1.0811 - val_accuracy: 0.5733
# Epoch 73/125
# 425/425 [==============================] - 0s 1ms/step - loss: 0.9610 - accuracy: 0.5106 - val_loss: 0.9442 - val_accuracy: 0.6000
# Epoch 74/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9480 - accuracy: 0.5153 - val_loss: 1.2541 - val_accuracy: 0.5867
# Epoch 75/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9158 - accuracy: 0.5600 - val_loss: 1.3137 - val_accuracy: 0.6267
# Epoch 76/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9166 - accuracy: 0.6235 - val_loss: 1.0727 - val_accuracy: 0.6933
# Epoch 77/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8944 - accuracy: 0.6306 - val_loss: 0.9965 - val_accuracy: 0.5467
# Epoch 78/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9144 - accuracy: 0.5176 - val_loss: 0.8257 - val_accuracy: 0.6667
# Epoch 79/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8878 - accuracy: 0.5718 - val_loss: 0.9745 - val_accuracy: 0.4400
# Epoch 80/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8908 - accuracy: 0.5624 - val_loss: 0.9058 - val_accuracy: 0.5733
# Epoch 81/125
# 425/425 [==============================] - 0s 1ms/step - loss: 0.8813 - accuracy: 0.6376 - val_loss: 0.8722 - val_accuracy: 0.6667
# Epoch 82/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9696 - accuracy: 0.5318 - val_loss: 1.1906 - val_accuracy: 0.4267
# Epoch 83/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9692 - accuracy: 0.5059 - val_loss: 0.9842 - val_accuracy: 0.5733
# Epoch 84/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8670 - accuracy: 0.5341 - val_loss: 0.7500 - val_accuracy: 0.7200
# Epoch 85/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9627 - accuracy: 0.5153 - val_loss: 0.9367 - val_accuracy: 0.6533
# Epoch 86/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9806 - accuracy: 0.5671 - val_loss: 1.0113 - val_accuracy: 0.5867
# Epoch 87/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.
125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8680 - accuracy: 0.5741 - val_loss: 0.8276 - val_accuracy: 0.7200
# Epoch 118/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.8084 - accuracy: 0.6259 - val_loss: 0.8804 - val_accuracy: 0.6400
# Epoch 119/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.7880 - accuracy: 0.6141 - val_loss: 0.9679 - val_accuracy: 0.4533
# Epoch 120/125
# 425/425 [==============================] - 1s 1ms/step - loss: 1.0156 - accuracy: 0.5247 - val_loss: 1.3060 - val_accuracy: 0.5733
# Epoch 121/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9428 - accuracy: 0.4988 - val_loss: 1.0196 - val_accuracy: 0.5600
# Epoch 122/125
# 425/425 [==============================] - 1s 1ms/step - loss: 0.9118 - accuracy: 0.5247 - val_loss: 1.0511 - val_accuracy: 0.6800
# Epoch 123/125
# 425/425 [==============================] - 1s 2ms/step - loss: 0.8027 - accuracy: 0.6118 - val_loss: 0.9788 - val_accuracy: 0.7600
# Epoch 124/125
# 425/425 [==============================] - 1s 2ms/step - loss: 0.9072 - accuracy: 0.5671 - val_loss: 1.0478 - val_accuracy: 0.5600
# Epoch 125/125
# 425/425 [==============================] - 1s 2ms/step - loss: 0.9376 - accuracy: 0.5271 - val_loss: 1.0392 - val_accuracy: 0.4667

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(batch_size))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# - **Diagnose this curve w.r.t learning rate**:
#     - ANSWER:
# - Change learning rate to make this curve better

# %%
### Your answer
fit_model(X_train=X_train,y_train=y_train,X_test=X_test,y_test=y_test,n_batch=1)
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(1))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()
# Out:
# Epoch 1/125
# 425/425 [==============================] - 1s 2ms/step - loss: 3524930568192.0000 - accuracy: 0.4635 - val_loss: 20553089941504.0000 - val_accuracy: 0.6133
# Epoch 2/125
# 425/425 [==============================] - 1s 1ms/step - loss: 4808415635049906438144.0000 - accuracy: 0.4165 - val_loss: 239362573199851890147328.0000 - val_accuracy: 0.4533
# Epoch 3/125
# 425/425 [==============================] - 1s 1ms/step - loss: 167150182834025760546921381888.0000 - accuracy: 0.4588 - val_loss: 1076596421610293235671220879360.0000 - val_accuracy: 0.3600
# Epoch 4/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.4000 - val_loss: nan - val_accuracy: 0.4133
# Epoch 5/125
# 425/425 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 6/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 7/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 8/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 9/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 10/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 11/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 12/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 13/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 14/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 15/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 16/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 17/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 18/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 19/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 20/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 21/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 22/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 23/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 24/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 25/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 26/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 27/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 28/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 29/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 30/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 31/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 32/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 33/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 34/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 35/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 36/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 37/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 38/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 39/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 40/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 41/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 42/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 43/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 44/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 45/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 46/125
# 425/425 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 47/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 48/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 49/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 50/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 51/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 52/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 53/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 54/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 55/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 56/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 57/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 58/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 59/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 60/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 61/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 62/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 63/125
# 425/425 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 64/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 65/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 66/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 67/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 68/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 69/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 70/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 71/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 72/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 73/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 74/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 75/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 76/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 77/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 78/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 79/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 80/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 81/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 82/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 83/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 84/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 85/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 86/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 87/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 88/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 89/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 90/125
# 425/425 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 91/125
# 425/425 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 92/125
# 425/425 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 93/125
# 425/425 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 94/125
# 425/425 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 95/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 96/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 97/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 98/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 99/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 100/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 101/125
# 425/425 [==============================] - 0s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 102/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 103/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 104/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 105/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 106/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 107/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 108/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 109/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 110/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 111/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 112/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 113/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 114/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 115/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 116/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 117/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 118/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 119/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 120/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 121/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 122/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 123/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 124/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133
# Epoch 125/125
# 425/425 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.3294 - val_loss: nan - val_accuracy: 0.4133

# %% [markdown]
# ##### Size =  16

# %% [markdown]
# 10. **Retrain for 16 batch size**

# %%
### START CODE HERE ### 
history=fit_model(X_train=X_train,y_train=y_train,X_test=X_test,y_test=y_test,n_batch=16)
###### END CODE HERE
# Out:
# Epoch 1/125
# 27/27 [==============================] - 0s 6ms/step - loss: 2.6417 - accuracy: 0.5200 - val_loss: 4.3492 - val_accuracy: 0.5467
# Epoch 2/125
# 27/27 [==============================] - 0s 3ms/step - loss: 2.0049 - accuracy: 0.6071 - val_loss: 0.8887 - val_accuracy: 0.7067
# Epoch 3/125
# 27/27 [==============================] - 0s 2ms/step - loss: 1.1686 - accuracy: 0.6282 - val_loss: 1.0949 - val_accuracy: 0.6133
# Epoch 4/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.9734 - accuracy: 0.6824 - val_loss: 0.7796 - val_accuracy: 0.7200
# Epoch 5/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5979 - accuracy: 0.7318 - val_loss: 0.4916 - val_accuracy: 0.7600
# Epoch 6/125
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5623 - accuracy: 0.7624 - val_loss: 0.4569 - val_accuracy: 0.8400
# Epoch 7/125
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5527 - accuracy: 0.7741 - val_loss: 0.4404 - val_accuracy: 0.8533
# Epoch 8/125
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5206 - accuracy: 0.7835 - val_loss: 0.4388 - val_accuracy: 0.8400
# Epoch 9/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4923 - accuracy: 0.7882 - val_loss: 0.4693 - val_accuracy: 0.8000
# Epoch 10/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4822 - accuracy: 0.7882 - val_loss: 0.5341 - val_accuracy: 0.7333
# Epoch 11/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5282 - accuracy: 0.7765 - val_loss: 0.5891 - val_accuracy: 0.7867
# Epoch 12/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4682 - accuracy: 0.7976 - val_loss: 0.4267 - val_accuracy: 0.8267
# Epoch 13/125
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4809 - accuracy: 0.8047 - val_loss: 0.4200 - val_accuracy: 0.8267
# Epoch 14/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4629 - accuracy: 0.7859 - val_loss: 0.4714 - val_accuracy: 0.8000
# Epoch 15/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4479 - accuracy: 0.7953 - val_loss: 0.6645 - val_accuracy: 0.6667
# Epoch 16/125
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6624 - accuracy: 0.7435 - val_loss: 0.4734 - val_accuracy: 0.7733
# Epoch 17/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4678 - accuracy: 0.8071 - val_loss: 0.4933 - val_accuracy: 0.7333
# Epoch 18/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4371 - accuracy: 0.8071 - val_loss: 0.4187 - val_accuracy: 0.7867
# Epoch 19/125
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4220 - accuracy: 0.8094 - val_loss: 0.4731 - val_accuracy: 0.7467
# Epoch 20/125
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4652 - accuracy: 0.7906 - val_loss: 0.4161 - val_accuracy: 0.7867
# Epoch 21/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4126 - accuracy: 0.8235 - val_loss: 0.4386 - val_accuracy: 0.8000
# Epoch 22/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4259 - accuracy: 0.8141 - val_loss: 0.5011 - val_accuracy: 0.7733
# Epoch 23/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4169 - accuracy: 0.8165 - val_loss: 0.4324 - val_accuracy: 0.7867
# Epoch 24/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4544 - accuracy: 0.7929 - val_loss: 0.4275 - val_accuracy: 0.7867
# Epoch 25/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4235 - accuracy: 0.8188 - val_loss: 0.4836 - val_accuracy: 0.7867
# Epoch 26/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4329 - accuracy: 0.8141 - val_loss: 0.4653 - val_accuracy: 0.8267
# Epoch 27/125
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4594 - accuracy: 0.8259 - val_loss: 0.4949 - val_accuracy: 0.7600
# Epoch 28/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4259 - accuracy: 0.8188 - val_loss: 0.4362 - val_accuracy: 0.7733
# Epoch 29/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4156 - accuracy: 0.8306 - val_loss: 0.4422 - val_accuracy: 0.7733
# Epoch 30/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4113 - accuracy: 0.8141 - val_loss: 0.4616 - val_accuracy: 0.7333
# Epoch 31/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4365 - accuracy: 0.8188 - val_loss: 0.4440 - val_accuracy: 0.7867
# Epoch 32/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.8047 - val_loss: 0.4925 - val_accuracy: 0.7733
# Epoch 33/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4218 - accuracy: 0.8212 - val_loss: 0.4562 - val_accuracy: 0.7867
# Epoch 34/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4483 - accuracy: 0.7976 - val_loss: 0.4806 - val_accuracy: 0.7867
# Epoch 35/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4437 - accuracy: 0.8000 - val_loss: 0.4560 - val_accuracy: 0.7867
# Epoch 36/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4334 - accuracy: 0.8094 - val_loss: 0.4554 - val_accuracy: 0.8000
# Epoch 37/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4247 - accuracy: 0
125
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3807 - accuracy: 0.8235 - val_loss: 0.4561 - val_accuracy: 0.7600
# Epoch 118/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8282 - val_loss: 0.4814 - val_accuracy: 0.7733
# Epoch 119/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3789 - accuracy: 0.8212 - val_loss: 0.4921 - val_accuracy: 0.7333
# Epoch 120/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3887 - accuracy: 0.8282 - val_loss: 0.4405 - val_accuracy: 0.7733
# Epoch 121/125
# 27/27 [==============================] - 0s 3ms/step - loss: 0.3944 - accuracy: 0.8282 - val_loss: 0.4607 - val_accuracy: 0.7733
# Epoch 122/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3815 - accuracy: 0.8235 - val_loss: 0.4735 - val_accuracy: 0.7733
# Epoch 123/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3808 - accuracy: 0.8376 - val_loss: 0.4949 - val_accuracy: 0.7867
# Epoch 124/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3773 - accuracy: 0.8400 - val_loss: 0.4762 - val_accuracy: 0.7467
# Epoch 125/125
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3787 - accuracy: 0.8259 - val_loss: 0.4862 - val_accuracy: 0.7600

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(batch_size))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ##### Size =  128

# %% [markdown]
# 10. **Retrain for 128 batch size**

# %%
### START CODE HERE ### 
history=fit_model(X_train=X_train,y_train=y_train,X_test=X_test,y_test=y_test,n_batch=128)
###### END CODE HERE
# Out:
# Epoch 1/125
# 4/4 [==============================] - 0s 46ms/step - loss: 2.7543 - accuracy: 0.2894 - val_loss: 1.5714 - val_accuracy: 0.4933
# Epoch 2/125
# 4/4 [==============================] - 0s 8ms/step - loss: 2.1980 - accuracy: 0.4494 - val_loss: 1.1079 - val_accuracy: 0.6400
# Epoch 3/125
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2767 - accuracy: 0.5906 - val_loss: 1.3058 - val_accuracy: 0.6267
# Epoch 4/125
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3066 - accuracy: 0.5765 - val_loss: 0.7739 - val_accuracy: 0.6533
# Epoch 5/125
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0335 - accuracy: 0.6165 - val_loss: 1.1574 - val_accuracy: 0.4533
# Epoch 6/125
# 4/4 [==============================] - 0s 8ms/step - loss: 1.4452 - accuracy: 0.5224 - val_loss: 0.7415 - val_accuracy: 0.6933
# Epoch 7/125
# 4/4 [==============================] - 0s 8ms/step - loss: 1.1239 - accuracy: 0.5976 - val_loss: 1.4057 - val_accuracy: 0.6533
# Epoch 8/125
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0502 - accuracy: 0.6282 - val_loss: 0.7201 - val_accuracy: 0.6533
# Epoch 9/125
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9681 - accuracy: 0.6071 - val_loss: 0.7456 - val_accuracy: 0.6933
# Epoch 10/125
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7996 - accuracy: 0.6588 - val_loss: 0.8574 - val_accuracy: 0.6400
# Epoch 11/125
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8185 - accuracy: 0.6682 - val_loss: 0.6428 - val_accuracy: 0.7333
# Epoch 12/125
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7448 - accuracy: 0.6471 - val_loss: 0.5389 - val_accuracy: 0.7733
# Epoch 13/125
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6956 - accuracy: 0.6776 - val_loss: 0.6030 - val_accuracy: 0.7467
# Epoch 14/125
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6343 - accuracy: 0.7224 - val_loss: 0.5445 - val_accuracy: 0.7867
# Epoch 15/125
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6010 - accuracy: 0.7224 - val_loss: 0.5507 - val_accuracy: 0.7733
# Epoch 16/125
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5836 - accuracy: 0.7388 - val_loss: 0.5688 - val_accuracy: 0.7733
# Epoch 17/125
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5813 - accuracy: 0.7365 - val_loss: 0.5215 - val_accuracy: 0.8133
# Epoch 18/125
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5623 - accuracy: 0.7576 - val_loss: 0.5451 - val_accuracy: 0.7600
# Epoch 19/125
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5850 - accuracy: 0.7271 - val_loss: 0.5091 - val_accuracy: 0.7867
# Epoch 20/125
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5565 - accuracy: 0.7435 - val_loss: 0.6056 - val_accuracy: 0.7067
# Epoch 21/125
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5842 - accuracy: 0.7294 - val_loss: 0.4962 - val_accuracy: 0.7867
# Epoch 22/125
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5480 - accuracy: 0.7882 - val_loss: 0.5396 - val_accuracy: 0.7600
# Epoch 23/125
# 4/4 [==============================] - 0s 8ms/step - loss: 0.
125
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4157 - accuracy: 0.8188 - val_loss: 0.4603 - val_accuracy: 0.8400
# Epoch 117/125
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4111 - accuracy: 0.8094 - val_loss: 0.4550 - val_accuracy: 0.7600
# Epoch 118/125
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4296 - accuracy: 0.8165 - val_loss: 0.4469 - val_accuracy: 0.8267
# Epoch 119/125
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4329 - accuracy: 0.8188 - val_loss: 0.4624 - val_accuracy: 0.8400
# Epoch 120/125
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4196 - accuracy: 0.8212 - val_loss: 0.5016 - val_accuracy: 0.7600
# Epoch 121/125
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4255 - accuracy: 0.8235 - val_loss: 0.5276 - val_accuracy: 0.7733
# Epoch 122/125
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4259 - accuracy: 0.8282 - val_loss: 0.5093 - val_accuracy: 0.7867
# Epoch 123/125
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4188 - accuracy: 0.8259 - val_loss: 0.5204 - val_accuracy: 0.7733
# Epoch 124/125
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4249 - accuracy: 0.8282 - val_loss: 0.4652 - val_accuracy: 0.8267
# Epoch 125/125
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4250 - accuracy: 0.8329 - val_loss: 0.4516 - val_accuracy: 0.7867

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(batch_size))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ##### Size =  Data

# %% [markdown]
# 10. **Retrain for length of data batch size**

# %%
### START CODE HERE ### 
history=fit_model(X_train=X_train,y_train=y_train,X_test=X_test,y_test=y_test,n_batch=len(X_train))
###### END CODE HERE
# Out:
# Epoch 1/125
# 1/1 [==============================] - 0s 383ms/step - loss: 4.1429 - accuracy: 0.4541 - val_loss: 2.3093 - val_accuracy: 0.5467
# Epoch 2/125
# 1/1 [==============================] - 0s 22ms/step - loss: 2.6713 - accuracy: 0.4400 - val_loss: 2.3870 - val_accuracy: 0.3067
# Epoch 3/125
# 1/1 [==============================] - 0s 23ms/step - loss: 2.2378 - accuracy: 0.3153 - val_loss: 2.3886 - val_accuracy: 0.3067
# Epoch 4/125
# 1/1 [==============================] - 0s 23ms/step - loss: 2.0963 - accuracy: 0.3976 - val_loss: 1.3735 - val_accuracy: 0.5467
# Epoch 5/125
# 1/1 [==============================] - 0s 24ms/step - loss: 1.5320 - accuracy: 0.5082 - val_loss: 1.5730 - val_accuracy: 0.5600
# Epoch 6/125
# 1/1 [==============================] - 0s 34ms/step - loss: 1.7766 - accuracy: 0.4918 - val_loss: 0.8096 - val_accuracy: 0.6800
# Epoch 7/125
# 1/1 [==============================] - 0s 23ms/step - loss: 1.0068 - accuracy: 0.5906 - val_loss: 2.7776 - val_accuracy: 0.4667
# Epoch 8/125
# 1/1 [==============================] - 0s 23ms/step - loss: 2.5256 - accuracy: 0.4824 - val_loss: 0.9271 - val_accuracy: 0.6667
# Epoch 9/125
# 1/1 [==============================] - 0s 24ms/step - loss: 1.1430 - accuracy: 0.6024 - val_loss: 1.4919 - val_accuracy: 0.6400
# Epoch 10/125
# 1/1 [==============================] - 0s 24ms/step - loss: 1.6108 - accuracy: 0.5812 - val_loss: 1.4459 - val_accuracy: 0.6667
# Epoch 11/125
# 1/1 [==============================] - 0s 26ms/step - loss: 1.5098 - accuracy: 0.6024 - val_loss: 1.2063 - val_accuracy: 0.6400
# Epoch 12/125
# 1/1 [==============================] - 0s 24ms/step - loss: 1.2250 - accuracy: 0.6612 - val_loss: 1.9004 - val_accuracy: 0.3600
# Epoch 13/125
# 1/1 [==============================] - 0s 23ms/step - loss: 1.7192 - accuracy: 0.4447 - val_loss: 1.0157 - val_accuracy: 0.6400
# Epoch 14/125
# 1/1 [==============================] - 0s 23ms/step - loss: 1.1698 - accuracy: 0.6165 - val_loss: 1.1818 - val_accuracy: 0.6667
# Epoch 15/125
# 1/1 [==============================] - 0s 26ms/step - loss: 1.4202 - accuracy: 0.6000 - val_loss: 1.1653 - val_accuracy: 0.6533
# Epoch 16/125
# 1/1 [==============================] - 0s 38ms/step - loss: 1.4642 - accuracy: 0.6000 - val_loss: 1.0441 - val_accuracy: 0.6000
# Epoch 17/125
# 1/1 [==============================] - 0s 32ms/step - loss: 1.
125
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4979 - accuracy: 0.7859 - val_loss: 0.4729 - val_accuracy: 0.8000
# Epoch 109/125
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4973 - accuracy: 0.7859 - val_loss: 0.4726 - val_accuracy: 0.8000
# Epoch 110/125
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4960 - accuracy: 0.7929 - val_loss: 0.4725 - val_accuracy: 0.8000
# Epoch 111/125
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4953 - accuracy: 0.7859 - val_loss: 0.4705 - val_accuracy: 0.8000
# Epoch 112/125
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4940 - accuracy: 0.7953 - val_loss: 0.4690 - val_accuracy: 0.8000
# Epoch 113/125
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4933 - accuracy: 0.7882 - val_loss: 0.4683 - val_accuracy: 0.8000
# Epoch 114/125
# 1/1 [==============================] - 0s 34ms/step - loss: 0.4922 - accuracy: 0.7906 - val_loss: 0.4681 - val_accuracy: 0.8000
# Epoch 115/125
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4915 - accuracy: 0.7929 - val_loss: 0.4670 - val_accuracy: 0.8000
# Epoch 116/125
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4904 - accuracy: 0.7929 - val_loss: 0.4668 - val_accuracy: 0.8000
# Epoch 117/125
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4896 - accuracy: 0.7929 - val_loss: 0.4673 - val_accuracy: 0.8000
# Epoch 118/125
# 1/1 [==============================] - 0s 29ms/step - loss: 0.4886 - accuracy: 0.7953 - val_loss: 0.4674 - val_accuracy: 0.8000
# Epoch 119/125
# 1/1 [==============================] - 0s 26ms/step - loss: 0.4878 - accuracy: 0.7976 - val_loss: 0.4665 - val_accuracy: 0.8000
# Epoch 120/125
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4868 - accuracy: 0.7929 - val_loss: 0.4658 - val_accuracy: 0.8133
# Epoch 121/125
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4860 - accuracy: 0.7953 - val_loss: 0.4656 - val_accuracy: 0.8000
# Epoch 122/125
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4851 - accuracy: 0.7953 - val_loss: 0.4650 - val_accuracy: 0.8000
# Epoch 123/125
# 1/1 [==============================] - 0s 30ms/step - loss: 0.4842 - accuracy: 0.7953 - val_loss: 0.4640 - val_accuracy: 0.8133
# Epoch 124/125
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4834 - accuracy: 0.7953 - val_loss: 0.4636 - val_accuracy: 0.8133
# Epoch 125/125
# 1/1 [==============================] - 0s 28ms/step - loss: 0.4825 - accuracy: 0.7953 - val_loss: 0.4638 - val_accuracy: 0.8000

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(batch_size))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# 10. **What effect does changing batch size have on learning in terms of convergence and fluctuations?**
#
# **Answer:** There is less fluctuation on increasing the batch size and more convergence when increasing it.

# %% [markdown]
# #### Learning Rate

# %% [markdown]
# batch size 64

# %% [markdown]
# - **Use same code for build_model above, add an argument learning rate to change learning rate of optmizer**

# %%
def build_model(lr):
    
    ##### YOUR CODE HERE
    # define model
    initializer = tf.keras.initializers.HeUniform()
    model=tf.keras.models.Sequential([
    tf.keras.layers.Dense(50, activation=tf.nn.relu,kernel_initializer=initializer),
    tf.keras.layers.Dense(3,activation=tf.nn.softmax)
    ])
    # compile model
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=lr,momentum=0.9),loss=tf.keras.losses.categorical_crossentropy,metrics='accuracy')
    return model

# %% [markdown]
# ##### LR =  0.00001

# %% [markdown]
# 10. **Retrain for 0.00001 LR**

# %%
### START CODE HERE ### ()
build_model(lr)
# Print the model summary
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1408
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 84,097
# Trainable params: 84,097
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(batch_size))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ##### LR =  0.001

# %% [markdown]
# 10. **Retrain for 0.001 LR**

# %%
### START CODE HERE ### ()
build_model(0.001)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1408
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 84,097
# Trainable params: 84,097
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(batch_size))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ##### LR =  0.1

# %% [markdown]
# 10. **Retrain for 0.1 LR**

# %%
### START CODE HERE ### ()
build_model(0.1)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1408
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 84,097
# Trainable params: 84,097
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss vs. epochs, batch=' +str(batch_size))
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# 10. **What effect does changing learning rate have on learning?**
#
# **Answer:** The learning rate controls how quickly the model is adapted to the problem. Smaller learning rates require more training epochs given the smaller changes made to the weights each update, whereas larger learning rates result in rapid changes and require fewer training epochs
